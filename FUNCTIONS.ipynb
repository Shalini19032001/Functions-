# %% [markdown]
# # THEORY QUESTIONS

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# - A function is a block of reusable code that is independent and can be called anywhere in the program.
#
#
#   -  A method is a function that is associated with an object and is called using the object.
#
#  -  Example : def func():
#     return "Hello"
#
#     class Sample:
#       def method(self)
#
#  return "hello"

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
#
# - Parameters are variables listed in the function definition.
# - Arguments are values passed to the function when calling it.
#  - Example : def greet(name):
#     print(f"Hello, {"Tina"})
#
#     greet("Tina")

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
#
# - Positional arguments: Order matters.
# - Keyword arguments: Arguments are passed by name.
# - Default arguments: Parameters have default values.
# - Variable-length arguments:
# -*args for multiple positional args, **kwargs for multiple keyword args.
#
#  - Example:  def add(a, b=5):
#               return a + b
#
#           print(add(3, 4))  - positional
#           print(add(b=4, a=3))  - keyword
#               print(add(3)) - default

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#
# - It is used to return a value from a function.
#  - Example: def square(n):
#          return n * n
#          print(square(5))

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
#
#
# - Iterable: An object that can be iterated over (e.g., lists, tuples).
# - Iterator: An object that implements __iter__() and __next__()
#
#  Example: my_list = [1, 2, 3]
#         my_iter = iter(my_list)
#          print(next(my_iter))

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
# - Generators use yield instead of return and allow iteration without storing all values in memory.
#  - Example: def gen():
#              yield 1
#              yield 2
#              g = gen()
#             print(next(g))

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
# - Memory efficient, fast execution, and lazy evaluation.

# %% [markdown]
# 8.What is a lambda function in Python and when is it typically used?
# - A lambda function is a small anonymous function used where a short function is needed.
# - Example:
#            add=lambda x, y: x + y
#            print(add(3, 5))

# %% [markdown]
# 9.Explain the purpose and usage of the `map()` function in Python.
# - It applies a function to all elements in an iterable.
# - Example:
#          nums = [1, 2, 3]
#       squares = list(map(lambda x: x**2, nums))
#         print(squares)

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# - map(): Applies a function to all items.
# - reduce(): Performs cumulative operations.
# - filter(): Selects elements that meet a condition.
# -Example : from functools import reduce
#            nums = [1, 2, 3, 4]
#        print(list(map(lambda x: x*2, nums)))
#        print(reduce(lambda x, y: x + y, nums))
#        print(list(filter(lambda x: x % 2 == 0, nums)))

# %% [markdown]
# 11.
# - from functools import reduce
#
# -  List given
#        numbers = [47, 11, 42, 13]
#
# -   Using reduce() to sum the elements
#         result = reduce(lambda x, y: x + y, numbers)
#
# -     print(result)   Output: 113

# %% [markdown]
# #    PRACTICAL QUESTIONS

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.
#         def sum_even(nums):
#         return sum(x for x in nums if x % 2 == 0)
#
#         print(sum_even([1, 2, 3, 4, 5]))                                Output: 6

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.
#          def reverse_string(s):
#             return s[::-1]
#
#           print(reverse_string("hello"))      Output: "olleh"

# %% [markdown]
# 3.Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.
# - def square_list(nums):
#        return [x**2 for x in nums]
#
#   - print(square_list([1, 2, 3]))   Output: [1, 4, 9]

# %% [markdown]
# 4.Write a Python function that checks if a given number is prime or not from 1 to 200.
# - def is_prime(n):
#         if n < 2:
#         return False
#         for i in range(2, int(n ** 0.5) + 1):
#         if n % i == 0:
#             return False
#           return True
#
#        primes = [x for x in range(1, 201) if is_prime(x)]
#        print(primes)

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.
# - class Fibonacci:
#         def __init__(self, n):
#         self.n, self.a, self.b = n, 0, 1
#         def __iter__(self):
#         return self
#
#         def __next__(self):
#         if self.n <= 0:
#             raise StopIteration
#         self.n -= 1
#         self.a, self.b = self.b, self.a + self.b
#         return self.a
#
#         for num in Fibonacci(10):
#         print(num, end=" ")

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
# - def powers_of_2(n):
#           for i in range(n + 1):
#            yield 2 ** i
#
#          print(list(powers_of_2(5)))  Output: [1, 2, 4, 8, 16, 32]

# %% [markdown]
# 7.Implement a generator function that reads a file line by line and yields each line as a string.
#
# - Example:
#          def read_file(file_path):
#          with open(file_path, 'r') as f:
#         for line in f:
#          yield line.strip()

# %% [markdown]
# 8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
#
# - Example:
#           data = [(1, 3), (2, 2), (3, 1)]
#          sorted_data = sorted(data, key=lambda x: x[1])
#        print(sorted_data)      Output: [(3, 1), (2, 2), (1, 3)]

# %% [markdown]
# 9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
# - Example:
#           celsius = [0, 20, 37, 100]
#          fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
#          print(fahrenheit)   Output: [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
#
# - Example:
#           def remove_vowels(s):
#           return ''.join(filter(lambda x: x.lower() not in 'aeiou', s))
#
#        print(remove_vowels("hello world"))  Output: "hll wrld"

# %% [markdown]
# 11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.
#
# - List of orders with (Order Number, Book Title, Quantity, Price per Item)
# orders = [
#     (34587, "Learning Python, Mark Lutz", 4, 40.95),
#     (98762, "Programming Python, Mark Lutz", 5, 56.80),
#     (77226, "Head First Python, Paul Barry", 3, 32.95),
#     (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
# ]
#
# - Lambda function to calculate total price and apply a 10€ surcharge if total < 100€
# calculate_total = lambda order: (order[0], order[2] * order[3] + 10 if order[2] * order[3] < 100 else order[2] * order[3])
#
# - Applying map() to process all orders
# order_totals = list(map(calculate_total, orders))
#
# - Printing the result
# print(order_totals)
#
# - Output:
# - [(34587, 173.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]
